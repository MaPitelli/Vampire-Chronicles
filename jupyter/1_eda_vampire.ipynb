# %% [markdown]
# # EDA Analysis

# %%
import pandas as pd
import numpy as np

# Visualization
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # to be able to display all columns of the DataFrames

# %%
df = pd.read_csv("../data/vampire_characters.csv")
df.head(2)
# Out:
#                        Name  Age  Birth Year Country of Origin Vampire Clan  \
# 0           Jessica Elliott  104        1920          Botswana       Aether
# 1  Тамара Яковлевна Власова   19        2005            Тувалу       Vesper
#
#         Unique Ability Personality Trait Value or Belief  Fear or Weakness  \
# 0  Shadow Manipulation          Sociable   Self-Reliance          Darkness
# 1      Weather Control         Eccentric         Charity  Loss of Identity
#
#      Moral Alignment Special Skill or Knowledge                    Ambition  \
# 0       Neutral Fair           Mystical Rituals           Gain Divine Power
# 1  Neutral Pragmatic              Ancient Runes  Access Forbidden Knowledge
#
#             Secret  Strength  Dexterity  Constitution  Intelligence    Wisdom  \
# 0     Lost Kingdom  19.42246   10.51770       4.71113      11.33274  11.30068
# 1  Unknown History   8.55635    8.79903       3.73799       9.64790   2.71887
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78784 entries, 0 to 78783
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Name                        78784 non-null  object
#  1   Age                         78784 non-null  int64
#  2   Birth Year                  78784 non-null  int64
#  3   Country of Origin           78784 non-null  object
#  4   Vampire Clan                78784 non-null  object
#  5   Unique Ability              78784 non-null  object
#  6   Personality Trait           78784 non-null  object
#  7   Value or Belief             78784 non-null  object
#  8   Fear or Weakness            78784 non-null  object
#  9   Moral Alignment             78784 non-null  object
#  10  Special Skill or Knowledge  78784 non-null  object
#  11  Ambition                    78784 non-null  object
#  12  Secret                      78784 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Birth Year', 'Country of Origin', 'Vampire Clan',
#        'Unique Ability', 'Personality Trait', 'Value or Belief',
#        'Fear or Weakness', 'Moral Alignment', 'Special Skill or Knowledge',
#        'Ambition', 'Secret', 'Strength', 'Dexterity', 'Constitution',
#        'Intelligence', 'Wisdom', 'Charisma', 'Charm', 'Perception', 'Stealth',
#        'Ferocity', 'Beauty', 'Resilience', 'Madness', 'Honor', 'Combat Skill',
#        'Diplomacy Skill', 'Stealth Skill', 'Agility', 'Endurance',
#        'Manipulation', 'Arcane Knowledge', 'Physical Prowess', 'Health',
#        'Luck', 'Resourcefulness', 'Creativity', 'Focus', 'Speed', 'Precision',
#        'Adaptability', 'Martial Arts', 'Stealth Tactics', 'Negotiation',
#        'Investigation', 'Lore', 'Strategy', 'Survival Skills', 'Ancient Runes',
#        'Enhanced Reflexes', 'Telepathic Communication', 'Elemental Resistance',
#        'Mystic Aura', 'Ancient Relics Knowledge', 'Dark Humor', 'Night Vision',
# ...

# %%
df[['Age', 'Birth Year', 'Strength', 'Dexterity', 'Constitution',
       'Intelligence', 'Wisdom', 'Charisma', 'Charm', 'Perception', 'Stealth',
       'Ferocity', 'Beauty', 'Resilience', 'Madness', 'Honor', 'Combat Skill',
       'Diplomacy Skill', 'Stealth Skill', 'Agility', 'Endurance',
       'Manipulation', 'Arcane Knowledge', 'Physical Prowess', 'Health']].describe().T
# Out:
#                     count         mean         std    min          25%  \
# Age               78784.0   125.704712  112.459124   18.0    56.000000
# Birth Year        78784.0  1898.295288  112.459124 -361.0  1868.000000
# Strength          78784.0    11.090485    4.220249    0.0     8.182073
# Dexterity         78784.0     6.630042    2.616977    1.0     4.806215
# Constitution      78784.0     6.345244    3.124079    0.0     4.167312
# Intelligence      78784.0    11.119446    3.897910    0.0     8.443030
# Wisdom            78784.0     6.007197    2.945918    0.0     3.922435
# Charisma          78784.0     7.386973    3.177516    0.0     5.130993
# Charm             78784.0     8.216379    2.831891    0.0     6.262423
# Perception        78784.0     8.504758    3.477991    0.0     6.094182
# Stealth           78784.0     6.057749    3.118551    0.0     3.835533
# Ferocity          78784.0     8.541760    3.718335    0.0     5.982028
# ...

# %%
df[['Luck', 'Resourcefulness', 'Creativity', 'Focus', 'Speed', 'Precision',
       'Adaptability', 'Martial Arts', 'Stealth Tactics', 'Negotiation',
       'Investigation', 'Lore', 'Strategy', 'Survival Skills', 'Ancient Runes',
       'Enhanced Reflexes', 'Telepathic Communication', 'Elemental Resistance',
       'Mystic Aura', 'Ancient Relics Knowledge', 'Dark Humor', 'Night Vision',
       'Gothic Style Preference', 'Mystery Solving Ability']].describe().T
# Out:
#                             count      mean       std      min       25%  \
# Luck                      78784.0  6.962087  2.925710  0.00000  4.950970
# Resourcefulness           78784.0  8.003071  3.393517  0.00000  5.636093
# Creativity                78784.0  6.755025  2.796333  0.00000  4.827690
# Focus                     78784.0  7.306028  3.100052  0.00000  5.139150
# Speed                     78784.0  6.599893  2.796234  0.00000  4.673255
# Precision                 78784.0  6.539108  2.769626  0.00000  4.634405
# Adaptability              78784.0  6.932244  2.899734  0.00000  4.914645
# Martial Arts              78784.0  8.965296  3.550663  0.00000  6.502085
# Stealth Tactics           78784.0  6.215450  2.811994  0.00000  4.260745
# Negotiation               78784.0  6.583539  2.725515  0.00000  4.704702
# Investigation             78784.0  8.363530  3.239309  0.00000  6.096073
# Lore                      78784.0  7.948524  3.073658  0.00000  5.817210
# ...

# %%
df[['Historical Knowledge', 'Arcane Crafting', 'Shadow Manipulation',
       'Unholy Resilience', 'Disguise Skill', 'Tactical Mind',
       'Psychic Sensitivity', 'Invisibility Skill', 'Supernatural Perception',
       'Ancient Language Fluency', 'Blood Magic Expertise',
       'Psychic Shielding', 'Illusion Casting', 'Mystic Healing',
       'Gloom Manipulation', 'Haunting Presence', 'Dreamwalking',
       'Astral Projection', 'Mysticism', 'Survival']].describe().T
# Out:
#                             count      mean       std      min       25%  \
# Historical Knowledge      78784.0  4.980728  2.890672  0.00013  2.472408
# Arcane Crafting           78784.0  4.977368  2.883737  0.00019  2.482563
# Shadow Manipulation       78784.0  4.985825  2.888259  0.00000  2.489313
# Unholy Resilience         78784.0  4.999468  2.888405  0.00005  2.495448
# Disguise Skill            78784.0  5.006727  2.884183  0.00014  2.515383
# Tactical Mind             78784.0  4.994914  2.882196  0.00007  2.493457
# Psychic Sensitivity       78784.0  5.012892  2.883640  0.00005  2.515837
# Invisibility Skill        78784.0  4.995964  1.579393  0.00000  4.000000
# Supernatural Perception   78784.0  5.004455  2.239682  0.00000  3.000000
# Ancient Language Fluency  78784.0  5.014144  2.875405  0.00002  2.529187
# Blood Magic Expertise     78784.0  5.004748  2.890810  0.00008  2.506947
# Psychic Shielding         78784.0  5.013410  2.884678  0.00036  2.531773
# ...

# %%
df.describe(include="object").T
# Out:
#                             count unique                   top  freq
# Name                        78784  56692                 佐藤 香織    40
# Country of Origin           78784    680                 Korea   403
# Vampire Clan                78784     22                Xenoth  3714
# Unique Ability              78784     20              Hypnosis  4078
# Personality Trait           78784     88             Skeptical  1705
# Value or Belief             78784     44            Innovation  3560
# Fear or Weakness            78784     42              Darkness  1975
# Moral Alignment             78784     37     Neutral Pragmatic  4229
# Special Skill or Knowledge  78784     51           Trap Making  1621
# Ambition                    78784     72  Become Vampire Ruler  1171
# Secret                      78784     67   Unknown Connections  2382

# %%
df["Name"].duplicated().sum()
# Out:
# 22092

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.dtypes.value_counts()
# Out:
# float64    65
# object     11
# int64       4
# Name: count, dtype: int64

# %%
df["Vampire Clan"].unique()
# Out:
# array(['Aether', 'Vesper', 'Revenant', 'Luna', 'Enigma', 'Rexxar',
#        'Hades', 'Covenant', 'Gorgona', 'Helios', 'Xenoth', 'Nyx', 'Omen',
#        'Valkyr', 'Azura', 'Aurora', 'Duskborn', 'Ravenclaw', 'Eclipse',
#        'Hallowed', 'Tempest', 'Bane'], dtype=object)

# %%
df["Unique Ability"].unique()
# Out:
# array(['Shadow Manipulation', 'Weather Control', 'Flight',
#        'Time Manipulation', 'Invisibility', 'Super Strength',
#        'Mind Control', 'Telekinesis', 'Astral Projection', 'Regeneration',
#        'Shape-Shifting', 'Telepathic Communication', 'Blood Magic',
#        'Hypnosis', 'Elemental Control', 'Enhanced Senses', 'Telepathy',
#        'Shapeshifting', 'Healing Touch', 'Illusion Casting'], dtype=object)

# %%
df["Personality Trait"].unique()
# Out:
# array(['Sociable', 'Eccentric', 'Loyal', 'Hot-headed', 'Wise',
#        'Persistent', 'Observant', 'Tolerant', 'Proud', 'Doubtful',
#        'Reliable', 'Wary', 'Mischievous', 'Manipulative', 'Ambitious',
#        'Resourceful', 'Humorous', 'Proactive', 'Mysterious',
#        'Intelligent', 'Altruistic', 'Prideful', 'Discreet', 'Determined',
#        'Deceitful', 'Compassionate', 'Rebellious', 'Reserved', 'Brave',
#        'Sympathetic', 'Honest', 'Witty', 'Introverted', 'Benevolent',
#        'Aloof', 'Impulsive', 'Stubborn', 'Protective', 'Ambivalent',
#        'Gracious', 'Secretive', 'Curious', 'Forgiving', 'Empathetic',
#        'Meticulous', 'Pensive', 'Passionate', 'Naive', 'Disciplined',
#        'Patient', 'Resilient', 'Charismatic', 'Cunning', 'Creative',
#        'Thoughtful', 'Honorable', 'Skeptical', 'Playful', 'Adventurous',
#        'Selfish', 'Spiteful', 'Humble', 'Jealous', 'Calm', 'Assertive',
#        'Egotistical', 'Shy', 'Optimistic', 'Realistic', 'Gullible',
# ...

# %%
df["Value or Belief"].unique()
# Out:
# array(['Self-Reliance', 'Charity', 'Patriotism', 'Justice',
#        'Justice for All', 'Perseverance', 'Self-Improvement', 'Respect',
#        'Fairness', 'Growth', 'Independence', 'Unity', 'Humility',
#        'Harmony', 'Community', 'Innovation', 'Benevolence',
#        'Spirituality', 'Truth', 'Courage', 'Optimism', 'Revenge',
#        'Self-Sacrifice', 'Simplicity', 'Wisdom', 'Freedom', 'Adventure',
#        'Forgiveness', 'Order', 'Loyalty', 'Honor', 'Equality', 'Ambition',
#        'Knowledge', 'Chaos', 'Tradition', 'Empathy', 'Righteousness',
#        'Peace', 'Balance', 'Love', 'Resilience', 'Self-Preservation',
#        'Power'], dtype=object)

# %%
df["Special Skill or Knowledge"].unique()
# Out:
# array(['Mystical Rituals', 'Ancient Runes', 'Illusion Magic',
#        'Strategic Warfare', 'Historical Secrets', 'Alchemy',
#        'Wilderness Survival', 'Diplomacy', 'Navigational Skills',
#        'Stealth Tactics', 'Beast Mastery', 'Advanced Alchemy',
#        'Survival Instincts', 'Mythical Creatures', 'Trap Disarming',
#        'Healing Arts', 'Astronomy', 'Herbalism', 'Mechanical Engineering',
#        'Animal Companions', 'Military Strategy', 'Survival Techniques',
#        'Ancient Languages', 'Magical Artifacts', 'Ancient History',
#        'Political Strategy', 'Artifact Crafting', 'Divination',
#        'Ancient Prophecies', 'Ritual Combat', 'Arcane Rituals',
#        'Interrogation Techniques', 'Historical Research',
#        'Forensic Science', 'Shadow Arts', 'Mystic Arts', 'Sword Forging',
#        'Negotiation Skills', 'Heraldry', 'Swordsmanship',
#        'Occult Knowledge', 'Espionage', 'Rune Magic', 'Enchanting',
# ...

# %%
df["Ambition"].unique()
# Out:
# array(['Gain Divine Power', 'Access Forbidden Knowledge',
#        'Rebuild Lost Empires', 'Rewrite Vampire Laws',
#        'Find Cure for Vampirism', 'Create New Traditions',
#        'Unleash Hidden Potential', 'Create a Vampire Utopia',
#        'Discover New Frontiers', 'Secure a Throne',
#        'Achieve World Dominance', 'Master the Dark Arts', 'Start New Era',
#        'Build Safe Haven', 'Control the Night', 'Find Source of Power',
#        'Find Lost Artefacts', 'Harness Cosmic Forces',
#        'Control Vampire Factions', 'Break Free from Prophecies',
#        'Pursue Eternal Knowledge', 'Establish a Legacy',
#        'Develop New Magic', 'Influence Human Elite',
#        'Learn Ancient Languages', 'Create a New Age', 'Create New Clan',
#        'Balance Human and Vampire', 'Reclaim Ancient Lands',
#        'Protect Vampire Race', 'Hone Warrior Skills',
#        'Discover Ancient Secrets', 'Achieve Immortality',
#        'Conquer Human Nations', 'Seek Ultimate Power',
# ...

# %%
df["Country of Origin"].unique()
# Out:
# array(['Botswana', 'Тувалу', 'Equatorial Guinea', 'El Salvador', 'ガーナ',
#        'Korea', 'Rwanda', 'Colombia', 'Malawi', 'Iran', 'Andorra',
#        'Slovenia', 'Гондурас', 'Швеция', 'Montserrat', 'Bulgaria', 'Peru',
#        'Afghanistan', 'Indonesia', 'シリア', 'ドミニカ国', 'Italy', 'キプロス共和国',
#        "Cote d'Ivoire", 'パナマ', 'Бурунди', 'Croatia', 'Uzbekistan',
#        'Luxembourg', 'Canada', 'Мозамбик', 'Намибия', 'Namibia', 'Monaco',
#        'Chile', 'British Virgin Islands', 'Comoros', 'Бруней',
#        'Bosnia and Herzegovina', 'Cyprus', 'Saint Kitts and Nevis',
#        'Япония', 'マリ', 'トーゴ', 'Central African Republic', 'Словения',
#        'マラウィ', 'Austria', 'Jordan', 'Cape Verde', 'Seychelles',
#        'Singapore', 'Isle of Man', 'モンゴル', 'Kiribati', 'モロッコ',
#        'Montenegro', 'Tokelau', 'グリーンランド', 'ボスニア・ヘルツェゴビナ',
#        'French Guiana', 'Алжир', 'Slovakia (Slovak Republic)',
#        'Guinea-Bissau', 'Saint Barthelemy', 'Mauritania', 'Armenia',
# ...

# %%
df["Age"].describe()
# Out:
# count    78784.000000
# mean       125.704712
# std        112.459124
# min         18.000000
# 25%         56.000000
# 50%         93.000000
# 75%        156.000000
# max       2385.000000
# Name: Age, dtype: float64

# %%
df["Age"].dtype
# Out:
# dtype('int64')

# %%
df["Birth Year"][df["Birth Year"] < 0]
# Out:
# 25431   -295
# 49872   -361
# 61639   -306
# Name: Birth Year, dtype: int64

# %%
df[df["Birth Year"] < 0]
# Out:
#                            Name   Age  Birth Year Country of Origin  \
# 25431                     池田 健一  2319        -295              ネパール
# 49872          Samuel Rodriguez  2385        -361     Guinea-Bissau
# 61639  Леонид Эдгардович Власов  2330        -306        Сент-Люсия
#
#       Vampire Clan       Unique Ability Personality Trait Value or Belief  \
# 25431     Duskborn        Healing Touch             Naive     Benevolence
# 49872      Gorgona            Telepathy       Resourceful           Chaos
# 61639      Gorgona  Shadow Manipulation        Passionate         Harmony
#
#       Fear or Weakness    Moral Alignment Special Skill or Knowledge  \
# 25431           Silver  Neutral Pragmatic        Navigational Skills
# 49872         Darkness        Lawful Just          Animal Companions
# 61639         Weakness  Lawful Benevolent        Historical Research
#
#                      Ambition          Secret  Strength  Dexterity  \
# ...

# %%
df["Moral Alignment"].unique()
# Out:
# array(['Neutral Fair', 'Neutral Pragmatic', 'Lawful Idealistic',
#        'Lawful Benevolent', 'Chaotic Impulsive', 'Neutral Honest',
#        'Lawful Evil', 'Lawful Merciful', 'Lawful Malevolent',
#        'Chaotic Disruptive', 'Chaotic Anarchic', 'Neutral Evil',
#        'Neutral Wise', 'Lawful Righteous', 'Chaotic Reckless',
#        'Chaotic Evil', 'Neutral Cunning', 'Neutral Benevolent',
#        'Lawful Good', 'True Neutral', 'Chaotic Unpredictable',
#        'Chaotic Wild', 'Neutral Selfish', 'Lawful Just',
#        'Lawful Honorable', 'Lawful Dutiful', 'Neutral Good',
#        'Chaotic Good', 'Chaotic Neutral', 'Lawful Strategic',
#        'Chaotic Hedonistic', 'Lawful Protective', 'Chaotic Rebellious',
#        'Chaotic Altruistic', 'Lawful Neutral', 'Neutral Realistic',
#        'Neutral Adventurous'], dtype=object)

# %%
df["Fear or Weakness"].unique()
# Out:
# array(['Darkness', 'Loss of Identity', 'Loud Noises', 'Silver', 'Old Age',
#        'Sunlight', 'Addiction', 'Weakness', 'Paranoia', 'Failure',
#        'Inadequacy', 'Helplessness', 'Oblivion', 'Being Alone',
#        'Mental Instability', 'Rejection', 'Death', 'Corruption',
#        'Stagnation', 'Powerlessness', 'Betrayal', 'Guilt',
#        'Failure of Duty', 'Being Trapped', 'Insects', 'Fear of Change',
#        'Fear of Failure', 'Loss of Loved Ones', 'Judgment', 'Despair',
#        'Holy Water', 'The Unknown', 'Disease', 'Fire', 'Misfortune',
#        'Isolation', 'Manipulation', 'Vulnerability', 'Intolerance',
#        'Loss of Power', 'Weakness of the Flesh', 'Crowds'], dtype=object)

# %% [markdown]
# ## Steps to follow for cleaning
#
# - Normalize column names
# - Translate columns “Name” and “Country of Origin”.
# - Eliminate columns that we do not want for storytelling
# - Create a .csv with only the columns we will use for storytelling
